# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-180, 180, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 738

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        #Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        #Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_description = city_weather["weather"][0]["description"]
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": current_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | vardo
# Processing Record 3 of Set 1 | kavieng
# Processing Record 4 of Set 1 | mirina
# City not found. Skipping...
# Processing Record 5 of Set 1 | fereydun kenar
# Processing Record 6 of Set 1 | bayanday
# Processing Record 7 of Set 1 | dujuma
# City not found. Skipping...
# Processing Record 8 of Set 1 | ponta do sol
# Processing Record 9 of Set 1 | galiwinku
# City not found. Skipping...
# Processing Record 10 of Set 1 | tuatapere
# Processing Record 11 of Set 1 | saint-philippe
# Processing Record 12 of Set 1 | mar del plata
# Processing Record 13 of Set 1 | dikson
# Processing Record 14 of Set 1 | mogadishu
# Processing Record 15 of Set 1 | norman wells
# Processing Record 16 of Set 1 | tasiilaq
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | thinadhoo
# Processing Record 19 of Set 1 | tahe
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | puerto el triunfo
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 1 | ribeira grande
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | san ramon de la nueva oran
# Processing Record 28 of Set 1 | tiksi
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | bentiu
# Processing Record 31 of Set 1 | sangmelima
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | cascais
# Processing Record 34 of Set 1 | souillac
# Processing Record 35 of Set 1 | puerto ayora
# Processing Record 36 of Set 1 | ambodifototra
# City not found. Skipping...
# Processing Record 37 of Set 1 | hovd
# Processing Record 38 of Set 1 | adrar
# Processing Record 39 of Set 1 | chokurdakh
# Processing Record 40 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 41 of Set 1 | henties bay
# Processing Record 42 of Set 1 | hobart
# Processing Record 43 of Set 1 | mezibori
# Processing Record 44 of Set 1 | goderich
# Processing Record 45 of Set 1 | muscat
# Processing Record 46 of Set 1 | lebu
# Processing Record 47 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 1 | kapaa
# Processing Record 49 of Set 1 | leningradskiy
# Processing Record 50 of Set 1 | isangel
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | thompson
# Processing Record 3 of Set 2 | temir
# Processing Record 4 of Set 2 | xunchang
# Processing Record 5 of Set 2 | kokopo
# Processing Record 6 of Set 2 | ilhabela
# Processing Record 7 of Set 2 | carnarvon
# Processing Record 8 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 9 of Set 2 | nanortalik
# Processing Record 10 of Set 2 | qaqortoq
# Processing Record 11 of Set 2 | salinopolis
# Processing Record 12 of Set 2 | port elizabeth
# Processing Record 13 of Set 2 | morondava
# Processing Record 14 of Set 2 | vaini
# Processing Record 15 of Set 2 | harper
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | buzmeyin
# Processing Record 18 of Set 2 | whitehorse
# Processing Record 19 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 2 | waingapu
# Processing Record 21 of Set 2 | darnah
# Processing Record 22 of Set 2 | bambari
# Processing Record 23 of Set 2 | hastings
# Processing Record 24 of Set 2 | kasongo-lunda
# Processing Record 25 of Set 2 | puerto maldonado
# Processing Record 26 of Set 2 | gazanjyk
# Processing Record 27 of Set 2 | arlit
# Processing Record 28 of Set 2 | butaritari
# Processing Record 29 of Set 2 | hamilton
# Processing Record 30 of Set 2 | mananjary
# Processing Record 31 of Set 2 | huilong
# Processing Record 32 of Set 2 | kibala
# Processing Record 33 of Set 2 | vila franca do campo
# Processing Record 34 of Set 2 | sao joao da barra
# Processing Record 35 of Set 2 | port blair
# Processing Record 36 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 2 | naze
# Processing Record 38 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 2 | lahij
# Processing Record 40 of Set 2 | tuktoyaktuk
# Processing Record 41 of Set 2 | pisco
# Processing Record 42 of Set 2 | barrow
# Processing Record 43 of Set 2 | correntina
# Processing Record 44 of Set 2 | yellowknife
# Processing Record 45 of Set 2 | abadszalok
# Processing Record 46 of Set 2 | labuan
# Processing Record 47 of Set 2 | beruni
# City not found. Skipping...
# Processing Record 48 of Set 2 | bogande
# Processing Record 49 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 50 of Set 2 | kloulklubed
# Processing Record 1 of Set 3 | arraial do cabo
# Processing Record 2 of Set 3 | sinegorye
# Processing Record 3 of Set 3 | changping
# Processing Record 4 of Set 3 | torbay
# Processing Record 5 of Set 3 | iqaluit
# Processing Record 6 of Set 3 | pokrovsk
# Processing Record 7 of Set 3 | grindavik
# Processing Record 8 of Set 3 | atuona
# Processing Record 9 of Set 3 | broken hill
# Processing Record 10 of Set 3 | asmar
# Processing Record 11 of Set 3 | valkeala
# Processing Record 12 of Set 3 | yar-sale
# Processing Record 13 of Set 3 | broome
# Processing Record 14 of Set 3 | ambilobe
# Processing Record 15 of Set 3 | lubben
# Processing Record 16 of Set 3 | alice springs
# Processing Record 17 of Set 3 | jalu
# Processing Record 18 of Set 3 | mana
# Processing Record 19 of Set 3 | porto velho
# Processing Record 20 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 3 | port alfred
# Processing Record 22 of Set 3 | kaeo
# Processing Record 23 of Set 3 | esperance
# Processing Record 24 of Set 3 | salou
# Processing Record 25 of Set 3 | katsuura
# Processing Record 26 of Set 3 | san patricio
# Processing Record 27 of Set 3 | codrington
# Processing Record 28 of Set 3 | longyearbyen
# Processing Record 29 of Set 3 | sorkjosen
# Processing Record 30 of Set 3 | teguise
# Processing Record 31 of Set 3 | acajutla
# Processing Record 32 of Set 3 | hilo
# Processing Record 33 of Set 3 | port hardy
# Processing Record 34 of Set 3 | alta floresta
# Processing Record 35 of Set 3 | avarua
# Processing Record 36 of Set 3 | mendoza
# Processing Record 37 of Set 3 | saint george
# Processing Record 38 of Set 3 | hongjiang
# Processing Record 39 of Set 3 | vallenar
# Processing Record 40 of Set 3 | shakawe
# Processing Record 41 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 3 | vila velha
# Processing Record 43 of Set 3 | san cristobal
# Processing Record 44 of Set 3 | yichun
# Processing Record 45 of Set 3 | waipawa
# Processing Record 46 of Set 3 | dukat
# Processing Record 47 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 49 of Set 3 | zhigansk
# Processing Record 50 of Set 3 | tynda
# Processing Record 1 of Set 4 | coquimbo
# Processing Record 2 of Set 4 | bambous virieux
# Processing Record 3 of Set 4 | nacala
# Processing Record 4 of Set 4 | atherton
# Processing Record 5 of Set 4 | mahebourg
# Processing Record 6 of Set 4 | callaway
# Processing Record 7 of Set 4 | kodiak
# Processing Record 8 of Set 4 | dongobesh
# Processing Record 9 of Set 4 | cayenne
# Processing Record 10 of Set 4 | ilulissat
# Processing Record 11 of Set 4 | ostrovnoy
# Processing Record 12 of Set 4 | cherskiy
# Processing Record 13 of Set 4 | dutse
# Processing Record 14 of Set 4 | cidreira
# Processing Record 15 of Set 4 | mount gambier
# Processing Record 16 of Set 4 | buchanan
# Processing Record 17 of Set 4 | lisakovsk
# Processing Record 18 of Set 4 | shaunavon
# Processing Record 19 of Set 4 | kattivakkam
# Processing Record 20 of Set 4 | kahului
# Processing Record 21 of Set 4 | honiara
# Processing Record 22 of Set 4 | bredasdorp
# Processing Record 23 of Set 4 | castro
# Processing Record 24 of Set 4 | puro
# Processing Record 25 of Set 4 | muros
# Processing Record 26 of Set 4 | nome
# Processing Record 27 of Set 4 | mareeba
# Processing Record 28 of Set 4 | kutum
# Processing Record 29 of Set 4 | constitucion
# Processing Record 30 of Set 4 | bethel
# Processing Record 31 of Set 4 | isla vista
# Processing Record 32 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 4 | cairns
# Processing Record 34 of Set 4 | east london
# Processing Record 35 of Set 4 | margate
# Processing Record 36 of Set 4 | qaanaaq
# Processing Record 37 of Set 4 | saldanha
# Processing Record 38 of Set 4 | merauke
# Processing Record 39 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 4 | itarema
# Processing Record 41 of Set 4 | airai
# Processing Record 42 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 43 of Set 4 | sakakah
# Processing Record 44 of Set 4 | hofn
# Processing Record 45 of Set 4 | arak
# Processing Record 46 of Set 4 | yichang
# Processing Record 47 of Set 4 | bardiyah
# Processing Record 48 of Set 4 | auki
# Processing Record 49 of Set 4 | chuy
# Processing Record 50 of Set 4 | kaithal
# Processing Record 1 of Set 5 | vila
# Processing Record 2 of Set 5 | inverell
# Processing Record 3 of Set 5 | samana
# Processing Record 4 of Set 5 | yulara
# Processing Record 5 of Set 5 | yarega
# Processing Record 6 of Set 5 | faya
# Processing Record 7 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 5 | mporokoso
# Processing Record 9 of Set 5 | changli
# Processing Record 10 of Set 5 | lalupon
# Processing Record 11 of Set 5 | malartic
# Processing Record 12 of Set 5 | mudanya
# Processing Record 13 of Set 5 | san rafael
# Processing Record 14 of Set 5 | puerto colombia
# Processing Record 15 of Set 5 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 16 of Set 5 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 17 of Set 5 | tondano
# Processing Record 18 of Set 5 | las vegas
# Processing Record 19 of Set 5 | pires do rio
# Processing Record 20 of Set 5 | pacific grove
# Processing Record 21 of Set 5 | cukai
# Processing Record 22 of Set 5 | okhtyrka
# Processing Record 23 of Set 5 | san cataldo
# Processing Record 24 of Set 5 | pangnirtung
# Processing Record 25 of Set 5 | buritis
# Processing Record 26 of Set 5 | floro
# Processing Record 27 of Set 5 | ulaangom
# Processing Record 28 of Set 5 | san policarpo
# Processing Record 29 of Set 5 | upernavik
# Processing Record 30 of Set 5 | cape town
# Processing Record 31 of Set 5 | salym
# Processing Record 32 of Set 5 | talnakh
# Processing Record 33 of Set 5 | provideniya
# Processing Record 34 of Set 5 | bubaque
# Processing Record 35 of Set 5 | nikolskoye
# Processing Record 36 of Set 5 | lorengau
# Processing Record 37 of Set 5 | sinjar
# Processing Record 38 of Set 5 | hasaki
# Processing Record 39 of Set 5 | alofi
# Processing Record 40 of Set 5 | bayburt
# Processing Record 41 of Set 5 | biak
# Processing Record 42 of Set 5 | powassan
# Processing Record 43 of Set 5 | turukhansk
# Processing Record 44 of Set 5 | shush
# Processing Record 45 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 5 | kaniama
# Processing Record 47 of Set 5 | los llanos de aridane
# Processing Record 48 of Set 5 | north bend
# Processing Record 49 of Set 5 | kungurtug
# Processing Record 50 of Set 5 | afgoye
# City not found. Skipping...
# Processing Record 1 of Set 6 | deputatskiy
# Processing Record 2 of Set 6 | bata
# Processing Record 3 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 4 of Set 6 | tiruchchendur
# Processing Record 5 of Set 6 | macheng
# Processing Record 6 of Set 6 | luderitz
# Processing Record 7 of Set 6 | camana
# Processing Record 8 of Set 6 | coolum beach
# Processing Record 9 of Set 6 | maningrida
# Processing Record 10 of Set 6 | sorland
# Processing Record 11 of Set 6 | hualmay
# Processing Record 12 of Set 6 | clyde river
# Processing Record 13 of Set 6 | warrnambool
# Processing Record 14 of Set 6 | geraldton
# Processing Record 15 of Set 6 | georgetown
# Processing Record 16 of Set 6 | kaitangata
# Processing Record 17 of Set 6 | petropavl
# Processing Record 18 of Set 6 | san luis
# Processing Record 19 of Set 6 | faanui
# Processing Record 20 of Set 6 | guerrero negro
# Processing Record 21 of Set 6 | poum
# Processing Record 22 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 6 | baykit
# Processing Record 24 of Set 6 | erdenet
# Processing Record 25 of Set 6 | saint-joseph
# Processing Record 26 of Set 6 | andenes
# Processing Record 27 of Set 6 | vila do maio
# Processing Record 28 of Set 6 | sao filipe
# Processing Record 29 of Set 6 | matara
# Processing Record 30 of Set 6 | bay roberts
# Processing Record 31 of Set 6 | rafai
# Processing Record 32 of Set 6 | meridian
# Processing Record 33 of Set 6 | castlegar
# Processing Record 34 of Set 6 | hope
# Processing Record 35 of Set 6 | half moon bay
# Processing Record 36 of Set 6 | fohnsdorf
# Processing Record 37 of Set 6 | riyadh
# Processing Record 38 of Set 6 | etne
# Processing Record 39 of Set 6 | sirjan
# Processing Record 40 of Set 6 | mizan teferi
# Processing Record 41 of Set 6 | xingcheng
# Processing Record 42 of Set 6 | wonthaggi
# Processing Record 43 of Set 6 | trincomalee
# Processing Record 44 of Set 6 | mahanje
# Processing Record 45 of Set 6 | sola
# Processing Record 46 of Set 6 | neiafu
# Processing Record 47 of Set 6 | rangapara
# Processing Record 48 of Set 6 | pierre
# Processing Record 49 of Set 6 | vaasa
# Processing Record 50 of Set 6 | suntar
# Processing Record 1 of Set 7 | gengenbach
# Processing Record 2 of Set 7 | srivardhan
# Processing Record 3 of Set 7 | lumphat
# Processing Record 4 of Set 7 | sitka
# Processing Record 5 of Set 7 | mosquera
# Processing Record 6 of Set 7 | taoudenni
# Processing Record 7 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 7 | dingle
# Processing Record 9 of Set 7 | manggar
# Processing Record 10 of Set 7 | cabo san lucas
# Processing Record 11 of Set 7 | najran
# Processing Record 12 of Set 7 | itaueira
# Processing Record 13 of Set 7 | okato
# Processing Record 14 of Set 7 | saint-denis
# Processing Record 15 of Set 7 | khatanga
# Processing Record 16 of Set 7 | mersing
# Processing Record 17 of Set 7 | visby
# Processing Record 18 of Set 7 | matay
# Processing Record 19 of Set 7 | tura
# Processing Record 20 of Set 7 | mayfield
# Processing Record 21 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 7 | cockburn town
# Processing Record 23 of Set 7 | shchelyayur
# City not found. Skipping...
# Processing Record 24 of Set 7 | ankazoabo
# Processing Record 25 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 7 | san jose
# Processing Record 27 of Set 7 | ambon
# Processing Record 28 of Set 7 | ulverstone
# Processing Record 29 of Set 7 | hamadan
# Processing Record 30 of Set 7 | eyrarbakki
# Processing Record 31 of Set 7 | hithadhoo
# Processing Record 32 of Set 7 | gamba
# Processing Record 33 of Set 7 | kindu
# Processing Record 34 of Set 7 | sumbe
# Processing Record 35 of Set 7 | taywarah
# Processing Record 36 of Set 7 | koslan
# Processing Record 37 of Set 7 | makakilo city
# Processing Record 38 of Set 7 | tabou
# Processing Record 39 of Set 7 | luklukan
# Processing Record 40 of Set 7 | belturbet
# Processing Record 41 of Set 7 | bergneustadt
# Processing Record 42 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 43 of Set 7 | solnechnyy
# Processing Record 44 of Set 7 | springfield
# Processing Record 45 of Set 7 | nabire
# Processing Record 46 of Set 7 | mabiton
# Processing Record 47 of Set 7 | emerald
# Processing Record 48 of Set 7 | hirara
# Processing Record 49 of Set 7 | hobyo
# Processing Record 50 of Set 7 | rio grande
# Processing Record 1 of Set 8 | bull savanna
# Processing Record 2 of Set 8 | new norfolk
# Processing Record 3 of Set 8 | milwaukee
# Processing Record 4 of Set 8 | suchedniow
# Processing Record 5 of Set 8 | birjand
# Processing Record 6 of Set 8 | athabasca
# Processing Record 7 of Set 8 | tsurib
# Processing Record 8 of Set 8 | pemangkat
# Processing Record 9 of Set 8 | marawi
# Processing Record 10 of Set 8 | beni suef
# Processing Record 11 of Set 8 | rojhan
# Processing Record 12 of Set 8 | agirish
# Processing Record 13 of Set 8 | jumla
# Processing Record 14 of Set 8 | kyra
# Processing Record 15 of Set 8 | nehoiu
# Processing Record 16 of Set 8 | balao
# Processing Record 17 of Set 8 | narsaq
# Processing Record 18 of Set 8 | xichang
# Processing Record 19 of Set 8 | yenagoa
# Processing Record 20 of Set 8 | dunedin
# Processing Record 21 of Set 8 | koumac
# Processing Record 22 of Set 8 | palmer
# Processing Record 23 of Set 8 | aklavik
# Processing Record 24 of Set 8 | maposeni
# Processing Record 25 of Set 8 | somanda
# Processing Record 26 of Set 8 | tessalit
# Processing Record 27 of Set 8 | imamoglu
# Processing Record 28 of Set 8 | namatanai
# Processing Record 29 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 30 of Set 8 | mentougou
# Processing Record 31 of Set 8 | constantine
# Processing Record 32 of Set 8 | touros
# Processing Record 33 of Set 8 | barra do corda
# Processing Record 34 of Set 8 | ponta delgada
# Processing Record 35 of Set 8 | campbell river
# Processing Record 36 of Set 8 | do rud
# City not found. Skipping...
# Processing Record 37 of Set 8 | pevek
# Processing Record 38 of Set 8 | esso
# Processing Record 39 of Set 8 | port macquarie
# Processing Record 40 of Set 8 | atagay
# Processing Record 41 of Set 8 | nouadhibou
# Processing Record 42 of Set 8 | port-gentil
# Processing Record 43 of Set 8 | wankaner
# Processing Record 44 of Set 8 | giyani
# Processing Record 45 of Set 8 | beringovskiy
# Processing Record 46 of Set 8 | klyuchi
# Processing Record 47 of Set 8 | tarbes
# Processing Record 48 of Set 8 | kabinda
# Processing Record 49 of Set 8 | puerto narino
# Processing Record 50 of Set 8 | kruisfontein
# Processing Record 1 of Set 9 | quimper
# Processing Record 2 of Set 9 | coihaique
# Processing Record 3 of Set 9 | plettenberg bay
# Processing Record 4 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 5 of Set 9 | saskylakh
# Processing Record 6 of Set 9 | yatou
# Processing Record 7 of Set 9 | awjilah
# Processing Record 8 of Set 9 | longyan
# Processing Record 9 of Set 9 | sofiyivka
# Processing Record 10 of Set 9 | tabas
# Processing Record 11 of Set 9 | redmond
# Processing Record 12 of Set 9 | catalina
# Processing Record 13 of Set 9 | marzuq
# Processing Record 14 of Set 9 | wajir
# Processing Record 15 of Set 9 | rock sound
# Processing Record 16 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 9 | quelimane
# Processing Record 18 of Set 9 | dao
# Processing Record 19 of Set 9 | kalmunai
# Processing Record 20 of Set 9 | richards bay
# Processing Record 21 of Set 9 | weymouth
# Processing Record 22 of Set 9 | la ronge
# Processing Record 23 of Set 9 | tshikapa
# Processing Record 24 of Set 9 | mirnyy
# Processing Record 25 of Set 9 | pangody
# Processing Record 26 of Set 9 | te anau
# Processing Record 27 of Set 9 | mitsamiouli
# Processing Record 28 of Set 9 | belaya gora
# Processing Record 29 of Set 9 | port maria
# Processing Record 30 of Set 9 | solsvik
# City not found. Skipping...
# Processing Record 31 of Set 9 | gogrial
# Processing Record 32 of Set 9 | inuvik
# Processing Record 33 of Set 9 | grand gaube
# Processing Record 34 of Set 9 | egvekinot
# Processing Record 35 of Set 9 | choya
# Processing Record 36 of Set 9 | abu samrah
# Processing Record 37 of Set 9 | batemans bay
# Processing Record 38 of Set 9 | bintulu
# Processing Record 39 of Set 9 | ahipara
# Processing Record 40 of Set 9 | lagoa
# Processing Record 41 of Set 9 | kamenka
# Processing Record 42 of Set 9 | ziro
# Processing Record 43 of Set 9 | noumea
# Processing Record 44 of Set 9 | yangjiang
# Processing Record 45 of Set 9 | kapoeta
# Processing Record 46 of Set 9 | varhaug
# Processing Record 47 of Set 9 | chenzhou
# Processing Record 48 of Set 9 | vilhena
# Processing Record 49 of Set 9 | sungaipenuh
# Processing Record 50 of Set 9 | krasnozerskoye
# Processing Record 1 of Set 10 | hof
# Processing Record 2 of Set 10 | gorele
# Processing Record 3 of Set 10 | jiayuguan
# Processing Record 4 of Set 10 | yamada
# Processing Record 5 of Set 10 | bac lieu
# Processing Record 6 of Set 10 | santa cruz
# Processing Record 7 of Set 10 | byron bay
# Processing Record 8 of Set 10 | leh
# Processing Record 9 of Set 10 | bonthe
# Processing Record 10 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 10 | mangrol
# Processing Record 12 of Set 10 | touba
# Processing Record 13 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 10 | pedro carbo
# Processing Record 15 of Set 10 | kudat
# Processing Record 16 of Set 10 | konevo
# Processing Record 17 of Set 10 | upata
# Processing Record 18 of Set 10 | mehamn
# Processing Record 19 of Set 10 | gat
# Processing Record 20 of Set 10 | alakurtti
# Processing Record 21 of Set 10 | ratnagiri
# Processing Record 22 of Set 10 | colares
# Processing Record 23 of Set 10 | nelson bay
# Processing Record 24 of Set 10 | monatele
# City not found. Skipping...
# Processing Record 25 of Set 10 | trofors
# Processing Record 26 of Set 10 | svetlyy
# Processing Record 27 of Set 10 | lubango
# Processing Record 28 of Set 10 | hoogeveen
# Processing Record 29 of Set 10 | ajmer
# Processing Record 30 of Set 10 | pakwach
# City not found. Skipping...
# Processing Record 31 of Set 10 | keti bandar
# Processing Record 32 of Set 10 | yashkul
# Processing Record 33 of Set 10 | palauig
# Processing Record 34 of Set 10 | kaohsiung
# Processing Record 35 of Set 10 | belmonte
# Processing Record 36 of Set 10 | cervo
# Processing Record 37 of Set 10 | erzin
# Processing Record 38 of Set 10 | dwarka
# Processing Record 39 of Set 10 | labuhan
# Processing Record 40 of Set 10 | havre
# Processing Record 41 of Set 10 | djibo
# Processing Record 42 of Set 10 | altay
# Processing Record 43 of Set 10 | kill
# Processing Record 44 of Set 10 | inhambane
# Processing Record 45 of Set 10 | vestmannaeyjar
# Processing Record 46 of Set 10 | iralaya
# Processing Record 47 of Set 10 | fortuna
# Processing Record 48 of Set 10 | port lincoln
# Processing Record 49 of Set 10 | bokspits
# City not found. Skipping...
# Processing Record 50 of Set 10 | portland
# Processing Record 1 of Set 11 | aki
# Processing Record 2 of Set 11 | ahuimanu
# Processing Record 3 of Set 11 | storforshei
# Processing Record 4 of Set 11 | anito
# Processing Record 5 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 11 | myingyan
# Processing Record 7 of Set 11 | tarata
# Processing Record 8 of Set 11 | fernie
# Processing Record 9 of Set 11 | lompoc
# Processing Record 10 of Set 11 | rawson
# Processing Record 11 of Set 11 | stromness
# Processing Record 12 of Set 11 | olafsvik
# Processing Record 13 of Set 11 | novokruchininskiy
# Processing Record 14 of Set 11 | santa fe
# Processing Record 15 of Set 11 | ano mera
# Processing Record 16 of Set 11 | george
# Processing Record 17 of Set 11 | krasnoselkup
# Processing Record 18 of Set 11 | beisfjord
# Processing Record 19 of Set 11 | mount hagen
# Processing Record 20 of Set 11 | vostok
# Processing Record 21 of Set 11 | anloga
# Processing Record 22 of Set 11 | praia da vitoria
# Processing Record 23 of Set 11 | turan
# Processing Record 24 of Set 11 | severnoye
# Processing Record 25 of Set 11 | boulsa
# Processing Record 26 of Set 11 | lyangasovo
# Processing Record 27 of Set 11 | dinsor
# City not found. Skipping...
# Processing Record 28 of Set 11 | tobermory
# Processing Record 29 of Set 11 | san jeronimo
# Processing Record 30 of Set 11 | saint anthony
# Processing Record 31 of Set 11 | ucluelet
# Processing Record 32 of Set 11 | tanhacu
# Processing Record 33 of Set 11 | puli
# Processing Record 34 of Set 11 | barmer
# Processing Record 35 of Set 11 | okakarara
# Processing Record 36 of Set 11 | kirakira
# Processing Record 37 of Set 11 | flinders
# Processing Record 38 of Set 11 | mantua
# Processing Record 39 of Set 11 | sao borja
# Processing Record 40 of Set 11 | port hedland
# Processing Record 41 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 11 | sao gotardo
# Processing Record 43 of Set 11 | alihe
# Processing Record 44 of Set 11 | tunceli
# Processing Record 45 of Set 11 | yeroham
# Processing Record 46 of Set 11 | zhumadian
# Processing Record 47 of Set 11 | isakly
# Processing Record 48 of Set 11 | ballina
# Processing Record 49 of Set 11 | jaguey grande
# Processing Record 50 of Set 11 | durban
# Processing Record 1 of Set 12 | matagami
# Processing Record 2 of Set 12 | elizabeth city
# Processing Record 3 of Set 12 | buala
# Processing Record 4 of Set 12 | bartica
# Processing Record 5 of Set 12 | chuzhou
# Processing Record 6 of Set 12 | zhuanghe
# Processing Record 7 of Set 12 | college
# Processing Record 8 of Set 12 | sociedad
# Processing Record 9 of Set 12 | mardin
# Processing Record 10 of Set 12 | hami
# Processing Record 11 of Set 12 | pasinler
# Processing Record 12 of Set 12 | zyryanka
# Processing Record 13 of Set 12 | fairbanks
# Processing Record 14 of Set 12 | zyryanovsk
# Processing Record 15 of Set 12 | auraiya
# Processing Record 16 of Set 12 | ardistan
# City not found. Skipping...
# Processing Record 17 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 18 of Set 12 | ushtobe
# Processing Record 19 of Set 12 | cape coast
# Processing Record 20 of Set 12 | ludhiana
# Processing Record 21 of Set 12 | malakal
# Processing Record 22 of Set 12 | chateaubelair
# Processing Record 23 of Set 12 | araouane
# Processing Record 24 of Set 12 | along
# Processing Record 25 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 12 | fernley
# Processing Record 27 of Set 12 | ibra
# Processing Record 28 of Set 12 | siva
# Processing Record 29 of Set 12 | novouzensk
# Processing Record 30 of Set 12 | lerwick
# Processing Record 31 of Set 12 | dagana
# Processing Record 32 of Set 12 | umm kaddadah
# Processing Record 33 of Set 12 | beloha
# Processing Record 34 of Set 12 | andrelandia
# Processing Record 35 of Set 12 | sibolga
# Processing Record 36 of Set 12 | nishihara
# Processing Record 37 of Set 12 | maniitsoq
# Processing Record 38 of Set 12 | dunmore town
# Processing Record 39 of Set 12 | mandalgovi
# Processing Record 40 of Set 12 | ahumada
# City not found. Skipping...
# Processing Record 41 of Set 12 | oranjestad
# Processing Record 42 of Set 12 | san lorenzo
# Processing Record 43 of Set 12 | tautira
# Processing Record 44 of Set 12 | mapiri
# Processing Record 45 of Set 12 | tual
# Processing Record 46 of Set 12 | eyl
# Processing Record 47 of Set 12 | youhao
# Processing Record 48 of Set 12 | benin
# Processing Record 49 of Set 12 | hibbing
# Processing Record 50 of Set 12 | kieta
# Processing Record 1 of Set 13 | lukulu
# Processing Record 2 of Set 13 | bismarck
# Processing Record 3 of Set 13 | beaverlodge
# Processing Record 4 of Set 13 | bengkulu
# Processing Record 5 of Set 13 | mokhsogollokh
# Processing Record 6 of Set 13 | rio gallegos
# Processing Record 7 of Set 13 | dauphin
# Processing Record 8 of Set 13 | tanete
# Processing Record 9 of Set 13 | vanavara
# Processing Record 10 of Set 13 | shingu
# Processing Record 11 of Set 13 | husavik
# Processing Record 12 of Set 13 | lazo
# Processing Record 13 of Set 13 | le mars
# Processing Record 14 of Set 13 | thanh hoa
# Processing Record 15 of Set 13 | sinnamary
# Processing Record 16 of Set 13 | sirnak
# Processing Record 17 of Set 13 | atlantic city
# Processing Record 18 of Set 13 | tucurui
# Processing Record 19 of Set 13 | walvis bay
# Processing Record 20 of Set 13 | opotiki
# Processing Record 21 of Set 13 | anadyr
# Processing Record 22 of Set 13 | caninde de sao francisco
# Processing Record 23 of Set 13 | zhezkazgan
# Processing Record 24 of Set 13 | kamaishi
# Processing Record 25 of Set 13 | lavrentiya
# Processing Record 26 of Set 13 | vista hermosa
# Processing Record 27 of Set 13 | igunga
# Processing Record 28 of Set 13 | mahon
# Processing Record 29 of Set 13 | pitimbu
# Processing Record 30 of Set 13 | belgrade
# Processing Record 31 of Set 13 | polyarnyy
# Processing Record 32 of Set 13 | coos bay
# Processing Record 33 of Set 13 | lata
# Processing Record 34 of Set 13 | mariental
# Processing Record 35 of Set 13 | kosmynino
# Processing Record 36 of Set 13 | santa maria
# Processing Record 37 of Set 13 | lobatse
# Processing Record 38 of Set 13 | tazovskiy
# Processing Record 39 of Set 13 | amapa
# Processing Record 40 of Set 13 | nueva loja
# Processing Record 41 of Set 13 | ahtopol
# Processing Record 42 of Set 13 | lazaro cardenas
# Processing Record 43 of Set 13 | akyab
# Processing Record 44 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 45 of Set 13 | beziers
# Processing Record 46 of Set 13 | san francisco
# Processing Record 47 of Set 13 | petrolina
# Processing Record 48 of Set 13 | shirokiy
# Processing Record 49 of Set 13 | lingao
# Processing Record 50 of Set 13 | lashio
# Processing Record 1 of Set 14 | vung tau
# Processing Record 2 of Set 14 | camacha
# Processing Record 3 of Set 14 | salalah
# Processing Record 4 of Set 14 | butembo
# Processing Record 5 of Set 14 | ipojuca
# Processing Record 6 of Set 14 | manakara
# Processing Record 7 of Set 14 | severinia
# Processing Record 8 of Set 14 | finschhafen
# Processing Record 9 of Set 14 | sept-iles
# Processing Record 10 of Set 14 | bilibino
# Processing Record 11 of Set 14 | hay river
# Processing Record 12 of Set 14 | puerto ayacucho
# Processing Record 13 of Set 14 | gallup
# Processing Record 14 of Set 14 | pokhvistnevo
# Processing Record 15 of Set 14 | ayabaca
# Processing Record 16 of Set 14 | antofagasta
# Processing Record 17 of Set 14 | padang
# Processing Record 18 of Set 14 | yangshe
# Processing Record 19 of Set 14 | quesnel
# Processing Record 20 of Set 14 | berlevag
# Processing Record 21 of Set 14 | omboue
# Processing Record 22 of Set 14 | aden
# Processing Record 23 of Set 14 | medicina
# Processing Record 24 of Set 14 | eureka
# Processing Record 25 of Set 14 | santa cruz de tenerife
# Processing Record 26 of Set 14 | aswan
# Processing Record 27 of Set 14 | akonolinga
# Processing Record 28 of Set 14 | rio branco
# Processing Record 29 of Set 14 | mocuba
# Processing Record 30 of Set 14 | berberati
# Processing Record 31 of Set 14 | kupang
# Processing Record 32 of Set 14 | wajima
# Processing Record 33 of Set 14 | chichester
# Processing Record 34 of Set 14 | hede
# Processing Record 35 of Set 14 | sangar
# Processing Record 36 of Set 14 | dali
# Processing Record 37 of Set 14 | katha
# City not found. Skipping...
# Processing Record 38 of Set 14 | road town
# Processing Record 39 of Set 14 | sa kaeo
# Processing Record 40 of Set 14 | rosetta
# Processing Record 41 of Set 14 | great yarmouth
# Processing Record 42 of Set 14 | lyuban
# Processing Record 43 of Set 14 | bafra
# Processing Record 44 of Set 14 | novyy urengoy
# Processing Record 45 of Set 14 | bereda
# Processing Record 46 of Set 14 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 47 of Set 14 | saint-augustin
# Processing Record 48 of Set 14 | cap malheureux
# Processing Record 49 of Set 14 | porto walter
# Processing Record 50 of Set 14 | severo-kurilsk
# Processing Record 1 of Set 15 | nakhon thai
# Processing Record 2 of Set 15 | agadez
# Processing Record 3 of Set 15 | victoria
# Processing Record 4 of Set 15 | saurimo
# Processing Record 5 of Set 15 | vangaindrano
# Processing Record 6 of Set 15 | cajabamba
# Processing Record 7 of Set 15 | port hawkesbury
# Processing Record 8 of Set 15 | bundaberg
# Processing Record 9 of Set 15 | asau
# Processing Record 10 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 15 | pimentel
# Processing Record 12 of Set 15 | zanjan
# Processing Record 13 of Set 15 | carutapera
# Processing Record 14 of Set 15 | moree
# Processing Record 15 of Set 15 | gorontalo
# Processing Record 16 of Set 15 | paita
# Processing Record 17 of Set 15 | mwinilunga
# Processing Record 18 of Set 15 | bembibre
# Processing Record 19 of Set 15 | moerai
# Processing Record 20 of Set 15 | rafraf
# Processing Record 21 of Set 15 | gigmoto
# Processing Record 22 of Set 15 | huarmey
# Processing Record 23 of Set 15 | raudeberg
# Processing Record 24 of Set 15 | jamkhed
# Processing Record 25 of Set 15 | mayo
# Processing Record 26 of Set 15 | bagdarin
# Processing Record 27 of Set 15 | synya
# Processing Record 28 of Set 15 | ciras
# City not found. Skipping...
# Processing Record 29 of Set 15 | bilma
# Processing Record 30 of Set 15 | karawang
# Processing Record 31 of Set 15 | tromso
# Processing Record 32 of Set 15 | florianopolis
# Processing Record 33 of Set 15 | srednekolymsk
# Processing Record 34 of Set 15 | kallithea
# Processing Record 35 of Set 15 | guymon
# Processing Record 36 of Set 15 | buariki
# City not found. Skipping...
# Processing Record 37 of Set 15 | antibes
# Processing Record 38 of Set 15 | iwanai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 682

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Mataura -46.1927  168.8643     56.48        71         100
# 1           Vardo  70.3705   31.1107     46.38        93         100
# 2         Kavieng  -2.5744  150.7967     83.82        72          76
# 3  Fereydun Kenar  36.6864   52.5225     71.47        76          65
# 4        Bayanday  53.0661  105.5139     26.73        76          10
# 5    Ponta Do Sol  32.6667  -17.1000     71.71        74          48
# 6       Tuatapere -46.1333  167.6833     58.57        68          50
# 7  Saint-Philippe -21.3585   55.7679     65.79        78          53
# 8   Mar Del Plata -38.0023  -57.5575     55.94        82           0
# 9          Dikson  73.5069   80.5464     32.49        81          35
#
#    Wind Speed Country Current Description
# 0        3.27      NZ     overcast clouds
# 1       14.97      NO     overcast clouds
# 2       10.80      PG          light rain
# 3        1.66      IR       broken clouds
# 4        1.57      RU           clear sky
# 5        3.91      PT    scattered clouds
# 6        5.41      NZ    scattered clouds
# 7        9.19      RE       broken clouds
# 8       14.00      AR           clear sky
# 9       12.28      RU    scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Mataura      NZ -46.1927  168.8643     56.48        71         100
# 1           Vardo      NO  70.3705   31.1107     46.38        93         100
# 2         Kavieng      PG  -2.5744  150.7967     83.82        72          76
# 3  Fereydun Kenar      IR  36.6864   52.5225     71.47        76          65
# 4        Bayanday      RU  53.0661  105.5139     26.73        76          10
# 5    Ponta Do Sol      PT  32.6667  -17.1000     71.71        74          48
# 6       Tuatapere      NZ -46.1333  167.6833     58.57        68          50
# 7  Saint-Philippe      RE -21.3585   55.7679     65.79        78          53
# 8   Mar Del Plata      AR -38.0023  -57.5575     55.94        82           0
# 9          Dikson      RU  73.5069   80.5464     32.49        81          35
#
#    Wind Speed Current Description
# 0        3.27     overcast clouds
# 1       14.97     overcast clouds
# 2       10.80          light rain
# 3        1.66       broken clouds
# 4        1.57           clear sky
# 5        3.91    scattered clouds
# 6        5.41    scattered clouds
# 7        9.19       broken clouds
# 8       14.00           clear sky
# 9       12.28    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "cities.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
